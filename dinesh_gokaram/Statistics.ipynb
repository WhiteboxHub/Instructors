# %%
#mean  

# Number of pets each person owns


sample = [1, 3, 2, 5, 7, 0, 2, 3]
mean = sum(sample) / len(sample)
print(mean)
# Out:
# 2.875

# %%
#weighted mean

# Three exams of .20 weight each and final exam of .40 weight  


sample = [90, 80, 63, 87]
weights = [.20, .20, .20, .40]
weighted_mean = sum(s * w for s,w in zip(sample, weights)) / sum(weights)
print(weighted_mean)
# Out:
# 81.4

# %%
#median
import statistics

# Function to calculate the median
def calculate_median(data):
    return statistics.median(data)

# Example data
data = [7, 2, 3, 1, 6, 5, 4]

# Calculate and print the median
median = calculate_median(data)
print("Median:", median)
# Out:
# Median: 4

# %%
#mode
# Number of pets each person owns


from collections import defaultdict
sample = [1, 3, 2, 5, 7, 0, 2, 3]
def mode(values):
    counts = defaultdict(lambda: 0) 
    for s in values:
        counts[s] += 1
    max_count = max(counts.values())
    modes = [v for v in set(values) if counts[v] == max_count]
    return modes
print(mode(sample))
# Out:
# [2, 3]

# %%
#variance
# Number of pets each person owns


sample = [1, 3, 2, 5, 7, 0, 2, 3]
def variance(values):
    mean = sum(values) / len(values)
    var = sum((v - mean) ** 2 for v in values) / len(values)
    return var
print(variance(sample))
# Out:
# 4.359375

# %%
#standard deviation 

from math import sqrt
# Number of pets each person owns
sample = [1, 3, 2, 5, 7, 0, 2, 3]
def variance(values):
    mean = sum(values) / len(values)
    var = sum((v - mean) ** 2 for v in values) / len(values)
    return var
def std_dev(values):
    return sqrt(variance(values))
print(std_dev(sample))
# Out:
# 2.0879116360612584

# %%
from math import sqrt
# Filament samples
sample = [1.78, 1.75, 1.72, 1.74, 1.77]
def mean(values):
    return sum(sample) / len(sample)
def variance_sample(values):
    mean = sum(values) / len(values)
    var = sum((v - mean) ** 2 for v in values) / (len(values) - 1.0)
    return var
def std_dev_sample(values):
    return sqrt(variance_sample(values))
print("MEAN = {}".format(mean(sample))) # 1.752
print("STD DEV = {}".format(std_dev_sample(sample)))
# Out:
# MEAN = 1.752
# STD DEV = 0.023874672772626667

# %%
#standard deviation

import numpy as np
import statistics

# Generate random samples from a normal distribution
mean = 100
std_dev = 15
num_samples = 1000
samples = np.random.normal(mean, std_dev, num_samples)

# Calculate statistics
mean_value = np.mean(samples)
median_value = np.median(samples)
variance_value = np.var(samples)
std_dev_value = np.std(samples)

# Print statistics
print("Mean:", mean_value)
print("Median:", median_value)
print("Variance:", variance_value)
print("Standard Deviation:", std_dev_value)
# Out:
# Mean: 100.26309742078848
# Median: 100.5468983470252
# Variance: 224.05133623947404
# Standard Deviation: 14.96834447223453

# %%
#Standard Normal Distribution and Z-Scores

def z_score(x, mean, std):
    return (x - mean) / std
def z_to_x(z, mean, std):
    return (z * std) + mean
mean = 6.0
std_dev = 1.0
x = 8.0
# Convert to Z-score and then back to X
z = z_score(x, mean, std_dev)
back_to_x = z_to_x(z, mean, std_dev)
print("Z-Score: {}".format(z)) # Z-Score: 2.0
print("Back to X: {}".format(back_to_x)) # Back to X: 8.0
# Out:
# Z-Score: 2.0
# Back to X: 8.0

# %%
#Cumulative Density Function (CDF)

from scipy.stats import norm
mean = 64.43
std_dev = 2.99
x = norm.cdf(66, mean, std_dev) - norm.cdf(62, mean, std_dev)
print(x)
# Out:
# 0.4920450147062894

# %%
#Cumulative Density Function (CDF)


import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def cdf(x, pdf):
    """
    Compute the Cumulative Density Function (CDF) from a given Probability Density Function (PDF).
    
    Parameters:
        x (array-like): Input values.
        pdf (array-like): Probability Density Function values corresponding to input values.
        
    Returns:
        array-like: Cumulative Density Function values.
    """
    cdf_values = np.zeros_like(x)
    for i in range(len(x)):
        cdf_values[i] = np.trapz(pdf[:i+1], x[:i+1])
    return cdf_values

# Example: Normal Distribution
mu = 0
sigma = 1
x_values = np.linspace(-5, 5, 1000)
pdf_values = norm.pdf(x_values, mu, sigma)
cdf_values = cdf(x_values, pdf_values)

# Plotting
plt.plot(x_values, cdf_values, label='CDF')
plt.xlabel('x')
plt.ylabel('Cumulative Probability')
plt.title('Cumulative Density Function (CDF)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#QUANTILE FUNCTION


import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def quantile(probabilities, cdf, x):
    """
    Compute the quantile function.

    Parameters:
        probabilities (array-like): Probabilities for which quantile values are to be computed.
        cdf (array-like): Cumulative Density Function values corresponding to input values x.
        x (array-like): Input values.

    Returns:
        array-like: Quantile function values.
    """
    quantiles = []
    for p in probabilities:
        idx = np.argmax(cdf >= p)
        quantiles.append(x[idx])
    return np.array(quantiles)

# Example: Normal Distribution
mu = 0
sigma = 1
x_values = np.linspace(-5, 5, 1000)
pdf_values = norm.pdf(x_values, mu, sigma)
cdf_values = norm.cdf(x_values, mu, sigma)

# Probabilities for which to compute quantiles
probabilities = np.linspace(0.01, 0.99, 10)

# Compute quantile function
quantiles = quantile(probabilities, cdf_values, x_values)

# Plotting
plt.plot(probabilities, quantiles, marker='o', linestyle='-')
plt.xlabel('Probability')
plt.ylabel('Quantile')
plt.title('Quantile Function')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
population_mean = 100  # Mean of the population
population_std = 15    # Standard deviation of the population
sample_size = 100      # Sample size
num_samples = 1000     # Number of samples

# Generate samples and compute sample means
sample_means = []
for _ in range(num_samples):
    sample = np.random.normal(population_mean, population_std, sample_size)
    sample_mean = np.mean(sample)
    sample_means.append(sample_mean)

# Plotting histogram of sample means
plt.hist(sample_means, bins=30, density=True, alpha=0.6, color='b')

# Plotting theoretical normal distribution
sample_mean_std = population_std / np.sqrt(sample_size)
sample_mean_mean = population_mean
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, sample_mean_mean, sample_mean_std)
plt.plot(x, p, 'k', linewidth=2)

# Labels and title
plt.xlabel('Sample Mean')
plt.ylabel('Frequency')
plt.title('Central Limit Theorem Demonstration')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 25
#      23 xmin, xmax = plt.xlim()
#      24 x = np.linspace(xmin, xmax, 100)
# ---> 25 p = norm.pdf(x, sample_mean_mean, sample_mean_std)
#      26 plt.plot(x, p, 'k', linewidth=2)
#      28 # Labels and title
#
# NameError: name 'norm' is not defined

# %%
#Confidence Intervals

from scipy.special import erfinv
from math import sqrt
def inv_normal_cdf(p: float, mean: float, std_dev: float):
    return mean + (std_dev * (2.0 ** 0.5) * erfinv((2.0 * p) - 1.0))
def z_to_x(z, mean, std):
    return (z * std) + mean
def critical_z_value(p, mean=0.0, std=1.0):
    left_area = (1.0 - p) / 2.0
    right_area = 1.0 - ((1.0 - p) / 2.0)
    lower_cutoff = inv_normal_cdf(left_area, mean, std)
    upper_cutoff = inv_normal_cdf(right_area, mean, std)
    return lower_cutoff, upper_cutoff
def ci_large_sample(p, sample_mean, sample_std, n):
# Sample size must be greater than 30
    lower, upper = critical_z_value(p)
    lower_ci = lower * (sample_std / sqrt(n))
    upper_ci = upper * (sample_std / sqrt(n))
    return sample_mean + lower_ci, sample_mean + upper_ci
# What is the confidence interval my sample of 31 golden retrievers
# with sample mean of 65.13, sample std of 2.05?
print(ci_large_sample(p=.95, sample_mean=65.13, sample_std=2.05, n=31))
# Out:
# (64.40835915701992, 65.85164084298007)

# %%
#Confidence Intervals


from math import sqrt
from scipy.stats import norm
def critical_z_value(p, mean=0.0, std=1.0):
    norm_dist = norm(loc=mean, scale=std)
    left_area = (1.0 - p) / 2.0
    right_area = 1.0 - ((1.0 - p) / 2.0)
    return norm_dist.ppf(left_area), norm_dist.ppf(right_area)
def ci_large_sample(p, sample_mean, sample_std, n):
# Sample size must be greater than 30
    lower, upper = critical_z_value(p)
    lower_ci = lower * (sample_std / sqrt(n))
    upper_ci = upper * (sample_std / sqrt(n))
    return sample_mean + lower_ci, sample_mean + upper_ci
# What is the confidence interval my sample of 31 golden retrievers
# with sample mean of 65.13, sample std of 2.05?
print(ci_large_sample(p=.95, sample_mean=65.13, sample_std=2.05, n=31))
# Out:
# (64.40835915701992, 65.85164084298007)

# %%
#Z-Test


from scipy.stats import norm
# Cold has 18 day mean recovery, 1.5 std dev
mean = 18
std_dev = 1.5
# 95% of probability is within 2 standard deviations
x = norm.cdf(21, mean, std_dev) - norm.cdf(15, mean, std_dev)
print(x)
# Out:
# 0.9544997361036416

# %%
#Confidence Intervals for Small Samples
from math import sqrt
from scipy.stats import t
def critical_t_value(p, n):
    t_dist = t(df=n - 1)
    left_area = (1.0 - p) / 2.0
    right_area = 1.0 - ((1.0 - p) / 2.0)
    return t_dist.ppf(left_area), t_dist.ppf(right_area)
def ci_small_sample(p, sample_mean, sample_std, n):
# Sample size must be greater than 30
    lower, upper = critical_t_value(p, n)
    lower_ci = lower * (sample_std / sqrt(n))
    upper_ci = upper * (sample_std / sqrt(n))
    return sample_mean + lower_ci, sample_mean + upper_ci
# What is the confidence interval my sample of 15 golden retrievers
# with sample mean of 65.13, sample std of 2.05?
print(ci_small_sample(p=.95, sample_mean=64.27, sample_std=2.75, n=15))
# Out:
# (62.74710076069723, 65.79289923930276)
